# %%
# !pip install pandas numpy scikit-learn
# Out:
# Requirement already satisfied: pandas in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (2.2.5)
# Requirement already satisfied: scikit-learn in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /u/49/anhdun1/unix/.virtualenvs/RCAEval-jrnb/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import warnings

import pandas as pd
from sklearn.preprocessing import RobustScaler

warnings.filterwarnings("ignore")


class Baro:
    def __init__(self):
        pass

    def run(
        self, dataset: pd.DataFrame, injection_time: int | None, top_k=5, **kwargs
    ) -> list[tuple[str, float]]:
        dataset.fillna(0, inplace=True)
        if "anomalies" not in kwargs:
            normal_df = dataset[dataset["timestamp"] < injection_time]
            anomal_df = dataset[dataset["timestamp"] >= injection_time]
        else:
            anomalies = kwargs["anomalies"]
            normal_df = dataset.head(anomalies[0])
            anomal_df = dataset.tail(len(dataset) - anomalies[0])

        # normal_df = preprocess(
        #     data=normal_df,
        #     dataset=None,
        #     dk_select_useful=kwargs.get("dk_select_useful", False),
        # )
        #
        # anomal_df = preprocess(
        #     data=anomal_df,
        #     dataset=None,
        #     dk_select_useful=kwargs.get("dk_select_useful", False),
        # )

        # intersect
        intersects = [x for x in normal_df.columns if x in anomal_df.columns]
        normal_df = normal_df[intersects]
        anomal_df = anomal_df[intersects]

        ranks = []

        for col in normal_df.columns:
            a = normal_df[col].to_numpy()
            b = anomal_df[col].to_numpy()

            scaler = RobustScaler().fit(a.reshape(-1, 1))
            zscores = scaler.transform(b.reshape(-1, 1))[:, 0]
            score = max(zscores)
            ranks.append((col, score))
        ranks = sorted(ranks, key=lambda x: x[1], reverse=True)

        print(ranks)
        ranks = [x[0] for x in ranks]

        return ranks[:top_k]

# %%
df = pd.read_csv("../tests/network_delay_preprocessing.csv")
pattern = r"\d{1,3}(?:\.\d{1,3}){3}"

# Drop columns matching the pattern
# df = df.drop(columns=df.filter(regex=pattern).columns)
# df = df.filter(regex='service|timestamp')

# %%
baro = Baro()
TOP_K = 10
injection_time = 1753426997 + 300
print(injection_time)
result = baro.run(df, top_k=TOP_K, injection_time=injection_time)
print(result)
# Out:
# 1753427297
# [('XXX.XXX.XXX.XXX_node:disk_written_sdd', np.float64(16384.0)), ('ensemble_service:p95_latency', np.float64(6428.865793780689)), ('XXX.XXX.XXX.XXX_node:network_receive_cilium_net', np.float64(4662.4)), ('XXX.XXX.XXX.XXX_node:network_transmit_cilium_host', np.float64(4662.4)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc56cdaf507bf5', np.float64(1794.2439024390233)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc4887cca15b32', np.float64(1755.5367709213965)), ('preprocessing_service:p95_latency', np.float64(1095.6146961846457)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc92af9227af0a', np.float64(1084.267)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc92af9227af0a', np.float64(974.7220039293541)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxcfd95003c8d25', np.float64(348.36975459206633)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc774f939bd154', np.float64(142.82941780821898)), ('XXX.XXX.XXX.XXX_node:disk_read_sdb', np.float64(136.533)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc57f8928f7a93', np.float64(108.37871764382929)), ('XXX.XXX.XXX.XXX_node:disk_read_dm-0', np.float64(108.21426817274265)), ('XXX.XXX.XXX.XXX_node:disk_read_vda', np.float64(108.21426817274265)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc0cc8dd1c90e8', np.float64(104.64943825732816)), ('XXX.XXX.XXX.XXX_node:disk_read_sda', np.float64(103.62711895035822)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc0cc8dd1c90e8', np.float64(97.77540704359322)), ('XXX.XXX.XXX.XXX_node:disk_read_dm-0', np.float64(97.54125413346999)), ('XXX.XXX.XXX.XXX_node:disk_read_vda', np.float64(97.54125413346999)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxcc4d0071c36d4', np.float64(92.92000000000009)), ('XXX.XXX.XXX.XXX_node:disk_written_dm-0', np.float64(92.46313753115298)), ('XXX.XXX.XXX.XXX_node:disk_written_vda', np.float64(92.46313753115298)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc57f8928f7a93', np.float64(89.89491837852063)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc56cdaf507bf5', np.float64(88.21301136363635)), ('XXX.XXX.XXX.XXX_node:network_receive_lxcc4d0071c36d4', np.float64(87.67338217338212)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc76b8b4b0bd96', np.float64(83.79819410235845)), ('XXX.XXX.XXX.XXX_node:disk_written_sda', np.float64(81.4403548030142)), ('XXX.XXX.XXX.XXX_node:disk_written_dm-0', np.float64(80.55089475705778)), ('XXX.XXX.XXX.XXX_node:disk_written_vda', np.float64(80.55089475705778)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc8c800829f901', np.float64(71.93440613755725)), ('XXX.XXX.XXX.XXX_node:disk_read_dm-0', np.float64(64.32711442178754)), ('XXX.XXX.XXX.XXX_node:disk_read_vda', np.float64(64.32711442178754)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc774f939bd154', np.float64(62.597983048731486)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc4887cca15b32', np.float64(59.5000000000003)), ('XXX.XXX.XXX.XXX_node:network_transmit_cilium_vxlan', np.float64(52.86767850464426)), ('XXX.XXX.XXX.XXX_node:network_transmit_enp1s0', np.float64(52.317072390368565)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc76b8b4b0bd96', np.float64(39.21333975702158)), ('XXX.XXX.XXX.XXX_node:disk_written_dm-0', np.float64(38.75366240543382)), ('XXX.XXX.XXX.XXX_node:disk_written_vda', np.float64(38.75366240543382)), ('preprocessing-7b7487499-n8x9x_pod:memory_usage', np.float64(24.014056224899598)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc8c800829f901', np.float64(21.46386830075268)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxcd17e9b7d0e61', np.float64(20.58361783626354)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxcff62ce89e638', np.float64(19.308340801023423)), ('preprocessing_service:memory_usage', np.float64(19.188712522045854)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc63bdcd96db16', np.float64(18.667)), ('XXX.XXX.XXX.XXX_node:network_receive_lxc52bcd25daf49', np.float64(18.667)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc4df20c750c62', np.float64(18.667)), ('XXX.XXX.XXX.XXX_node:network_transmit_lxc52bcd25daf49', np.float64(18.667)), ('XXX.XXX.XXX.XXX_node:network_receive_lxcb882d52 ...
# ['XXX.XXX.XXX.XXX_node:disk_written_sdd', 'ensemble_service:p95_latency', 'XXX.XXX.XXX.XXX_node:network_receive_cilium_net', 'XXX.XXX.XXX.XXX_node:network_transmit_cilium_host', 'XXX.XXX.XXX.XXX_node:network_receive_lxc56cdaf507bf5', 'XXX.XXX.XXX.XXX_node:network_transmit_lxc4887cca15b32', 'preprocessing_service:p95_latency', 'XXX.XXX.XXX.XXX_node:network_transmit_lxc92af9227af0a', 'XXX.XXX.XXX.XXX_node:network_receive_lxc92af9227af0a', 'XXX.XXX.XXX.XXX_node:network_transmit_lxcfd95003c8d25']

# %%
import matplotlib.pyplot as plt

# Filter data
filtered_df = df[df["timestamp"] > (injection_time - 50)].copy()

# Normalize selected columns (min-max scaling)
for col in result[:TOP_K]:
    min_val = filtered_df[col].min()
    max_val = filtered_df[col].max()
    filtered_df[col] = (filtered_df[col] - min_val) / (max_val - min_val)

# Plot
plt.figure(figsize=(30, 6))
for col in result[:TOP_K]:
    plt.plot(filtered_df["timestamp"], filtered_df[col], label=col)

plt.xlabel("Timestamp")
plt.ylabel("Normalized Value")
plt.title("Normalized Line Plot After Injection Time")
plt.legend()
plt.grid(True)
plt.show()
